# %%
import json
from pathlib import Path
import pandas as pd
from pprint import pprint
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
# Função para carregar arquivos JSON
def load_data(file_path):
    with open(file_path, "r") as file:
        return json.load(file)

# %%
files_dir = Path("processados/")

files = files_dir.glob("*.json")

instagram_files = files_dir.glob("instagram-*.json")
tiktok_files = files_dir.glob("tiktok-*.json")
youtube_files = files_dir.glob("YouTube-*.json")

all_files = {
    "Instagram": list(instagram_files),
    "TikTok": list(tiktok_files),
    "YouTube": list(youtube_files),
}

for select_name, selection_files in all_files.items():
    print(select_name.capitalize() + ":")
    for file_path in selection_files[:10]:
        print("\t- ", file_path)
# Out:
# Instagram:
# 	-  processados\instagram-2pac.json
# 	-  processados\instagram-30sertanejo.json
# 	-  processados\instagram-333cyj333.json
# 	-  processados\instagram-3gerardpique.json
# 	-  processados\instagram-9gag.json
# 	-  processados\instagram-abrunalouise.json
# 	-  processados\instagram-actorleeminho.json
# 	-  processados\instagram-adamlevine.json
# 	-  processados\instagram-adamsandler.json
# 	-  processados\instagram-adele.json
# Tiktok:
# 	-  processados\tiktok-._othy.json
# 	-  processados\tiktok-04h47min.json
# 	-  processados\tiktok-2depais.json
# 	-  processados\tiktok-7mz_lucas.json
# 	-  processados\tiktok-aalexiaevellyn.json
# 	-  processados\tiktok-aameliaamor.json
# 	-  processados\tiktok-abimaelranieri.json
# 	-  processados\tiktok-adestradormisterpet.json
# 	-  processados\tiktok-adrielzeira.json
# 	-  processados\tiktok-afbjoao.json
# Youtube:
# 	-  processados\youtube--clone.json
# 	-  processados\youtube-123GOCHALLENGEPortuguese.json
# 	-  processados\youtube-123GOLIKEPortuguese.json
# 	-  processados\youtube-123GOPortuguese.json
# 	-  processados\youtube-1KiloOficialTv.json
# 	-  processados\youtube-24HorasDeFutebol.json
# 	-  processados\youtube-3Sskaters.json
# 	-  processados\youtube-4AMIGOSSTANDUPCOMEDY.json
# 	-  processados\youtube-5algumacoisa.json
# 	-  processados\youtube-7minutoz.json

# %%
# Caminhos para arquivos de exemplo
instagram_file_path = files_dir / "instagram-ivetesangalo.json"
tiktok_file_path = files_dir / "tiktok-anitta.json"
youtube_file_path = files_dir / "youtube-brunoebarretto.json"

# Carregar dados de exemplo
instagram_example = load_data(instagram_file_path)
tiktok_example = load_data(tiktok_file_path)
youtube_example = load_data(youtube_file_path)

# %%
# Exibir dados de exemplo do Instagram
pprint(instagram_example)
# Out:
# {'_delta': None,
#  '_fh': None,
#  '_number': 617,
#  'basic': {'avatar_url': 'https://cdn.hypeauditor.com/img/instagram/user/13577008.jpg?w=150&till=1722470340&sign=e4e69bda8904aec68207c086296f2f67',
#            'fullname': 'Veveta',
#            'id': None,
#            'is_verified': True,
#            'social_id': '13577008',
#            'title': None,
#            'username': 'ivetesangalo'},
#  'features': {'audience_geo_country_1_code': 'br',
#               'audience_geo_country_1_prc': 81.28,
#               'blogger_thematics': {'data': [1027, 1017, 1032]}},
#  'metrics': {'authentic_engagement': {'value': 26728},
#              'engagement_avg': {'value': 39901},
#              'subscribers_count': {'value': 36741545}}}

# %% [markdown]
# ### Instagram Data (Exemplo: Ivete Sangalo)
#
# *Basic Information:*
#
# - social_id
#
# - username
#
# - fullname
#
# - avatar_url
#
# - is_verified
#
# *Features:*
#
# - audience_geo_country_1_code
#
# - audience_geo_country_1_prc
#
# - blogger_thematics
#
# *Metrics:*
# - authentic_engagement
# - engagement_avg
# - subscribers_count

# %%
# Exibir dados de exemplo do YouTube
pprint(youtube_example)
# Out:
# {'_delta': None,
#  '_number': 841,
#  'basic': {'avatar_url': 'https://yt3.googleusercontent.com/6HS_MzS0KpMcLwQjOAG0f3odOgZhUaHjMtM8AN7N_vlNLCz-Ka_h-slXVd-E9G0amOHqyQN-=s900-c-k-c0x00ffffff-no-rj',
#            'fullname': 'Bruno & Barretto',
#            'id': None,
#            'is_verified': False,
#            'social_id': 'UCPWqL6OWIZNO-dVm5euF-ng',
#            'title': None,
#            'username': 'brunoebarretto'},
#  'features': {'audience_geo': {'data': {'countries': [{'code': None,
#                                                        'hs_value': 0.001,
#                                                        'id': 'br',
#                                                        'prc': 98.44},
#                                                       {'code': None,
#                                                        'hs_value': None,
#                                                        'id': 'es',
#                                                        'prc': 0.35},
#                                                       {'code': None,
#                                                        'hs_value': None,
#                                                        'id': 'pt',
#                                                        'prc': 0.35},
#                                                       {'code': None,
#                                                        'hs_value': None,
#                                                        'id': 'us',
#                                                        'prc': 0.35},
#                                                       {'code': None,
#                                                        'hs_value': None,
#                                                        'id': 'fr',
#                                                        'prc': 0.17}]}},
#               'audience_geo_country_1_code': 'br',
#               'audience_geo_country_1_prc': 98.44,
#               'blogger_thematics': {'data': [17, 2]}},
#  'metrics': {'comments_avg': {'performance': {'30d': {'value': 7}}},
#              'engagement_avg': {'performance': {'30d': {'value': 153}}},
#              'likes_avg': {'performance': {'30d': {'value': 146}}},
#              'subscribers_count': {'value': 2391271},
#              'video_views_avg': {'performance': {'30d': {'value': 1577}}}}}

# %% [markdown]
# ### YouTube Data (Exemplo: Bruno & Barretto)
#
# *Basic Information:*
#
# - social_id
#
# - username
#
# - fullname
#
# - avatar_url
#
# - is_verified
#
# - title
#
# *Features:*
# - audience_geo
#
# - audience_geo_country_1_code
#
# - audience_geo_country_1_prc
#
# - blogger_thematics
#
# *Metrics:*
# - comments_avg
#
# - authentic_engagement
#
# - engagement_avg
#
# - subscribers_count
#
# - video_views_avg
#
# - likes_avg

# %%
# Exibir dados de exemplo do TikTok
pprint(tiktok_example)
# Out:
# {'_delta': None,
#  '_number': 394,
#  'basic': {'avatar_url': 'https://p16-va-tiktok.ibyteimg.com/tos-maliva-avt-0068/97461373b705a1908901736dd73373f9~c5_720x720.jpeg',
#            'description': 'FUNK GENERATION 🔊  Listen now',
#            'fullname': 'Anitta',
#            'is_public': True,
#            'is_verified': True,
#            'last_media_time': '2024-05-30',
#            'report_base_updated': '2024-06-01',
#            'report_data_updated': '2024-01-01',
#            'report_quality': 'FULL',
#            'report_state': 'READY',
#            'report_updated': '2024-06-05',
#            'report_version': '2020-08-17',
#            'social_id': '269624312792256512',
#            'social_type': 3,
#            'tier': 147,
#            'username': 'anitta',
#            'visibility_flags': 1},
#  'features': {'aqs': {'data': {'description': {'account_growth': {'description': {'title': {'key': 'GOOD_GROWTH',
#                                                                                             'text': 'Good '
#                                                                                                     'account '
#                                                                                                     'growth '
#                                                                                                     'rate'}},
#                                                                   'mark': 'good'},
#                                                'comments_likes_ratio': {'description': {'title': {'key': 'EXCL_CL_RATIO',
#                                                                                                   'text': 'Excellent '
#                                                                                                           'comments '
#                                                                                                           'to '
#                                                                                                           'likes '
#                                                                                                           'ratio'}},
#                                                                         'mark': 'excellent'},
#                                                'er': {'description': {'title': {'key': 'AVG_ER',
#                                                                                 'text': 'Average '
#                                                                                         'audience '
#                                                                                         'engagement'}},
#                                                       'mark': 'average'}},
#                                'mark': 'good',
#                                'mark_title': 'GOOD',
#                                'prc_better': 88,
#                                'value': 72}},
#               'blogger_geo': {'data': {'country': 'br'}}},
#  'metrics': {'alikes_avg': {'performance': {'30d': {'value': 30198}}},
#              'comments_avg': {'performance': {'30d': {'value': 589}}},
#              'er': {'performance': {'30d': {'mark': 'good',
#                                             'mark_title': 'GOOD',
#                                             'similar': 6.117799,
#                                             'similar_max': 7.083806,
#                                             'similar_min': 5.299669,
#                                             'value': 9.3,
#                                             'value_prev': 5.16}}},
#              'hs_value': {'value': 1326.837356},
#              'media_count': {'performance': {'30d': {'value': 16}}},
#              'shares_avg': {'performance': {'30d': {'value': 508}}},
#              'subscribers_count': {'value': 24164770},
#              'views_avg': {'performance': {'30d': {'value': 400528}}}}}

# %% [markdown]
# ### TikTok Data (Exemplo: Anitta)
#
# *Basic Information:*
#
# - social_id
#
# - username
#
# - fullname
#
# - description
#
# - is_verified
#
# - avatar_url
#
# *Features:*
#
# - aqs (audience quality score)
#
# - blogger_geo (geographic data)
#
# *Metrics:*
# - hs_values
#
# - subscribers_count
#
# - er (engagement rate)
#
# - views_avg
#
# - alikes_avg
#
# - comments_avg
#
# - shares_avg

# %%
# tratamento do arquivo thematics.json

thematics = json.load(open("thematics.json", "r", encoding="utf-8"))
thematics_trated = {}
sigla_map = {"ig": "Instagram", "yt": "YouTube", "tt": "TikTok"}
for key, value in thematics.items():
    thematics_trated[sigla_map[key]] = {}
    for key2, value2 in value.items():
        thematics_trated[sigla_map[key]].update({key2: value2["text"]})
thematics_trated
with open("thematics_trated.json", "w", encoding="utf-8") as f:
    json.dump(thematics_trated, f, indent=4, ensure_ascii=False)

# %%
import pandas as pd
import json
import os


def map_thematics(platform, thematics_ids):
    if not thematics_ids:
        return None
    return [
        thematics_trated[platform].get(str(t_id), "Unknown") for t_id in thematics_ids
    ]


def process_instagram_file(filepath):
    with open(filepath) as f:
        data = json.load(f)
    thematics_descriptions = map_thematics(
        "Instagram", data["features"]["blogger_thematics"]["data"]
    )
    return {
        "platform": "Instagram",
        "social_id": data["basic"]["social_id"],
        "username": data["basic"]["username"],
        "fullname": data["basic"]["fullname"],
        "avatar_url": data["basic"]["avatar_url"],
        "is_verified": data["basic"]["is_verified"],
        "subscribers_count": data["metrics"]["subscribers_count"]["value"],
        "engagement_avg": data["metrics"]["engagement_avg"]["value"],
        "authentic_engagement": data["metrics"]["authentic_engagement"]["value"],
        "audience_geo_country_1_code": data["features"]["audience_geo_country_1_code"],
        "audience_geo_country_1_prc": data["features"]["audience_geo_country_1_prc"],
        "blogger_thematics": thematics_descriptions,
        "video_views_avg": None,
        "likes_avg": None,
        "comments_avg": None,
        "shares_avg": None,
        "description": None,
        "tier": None,
        "hs_value": None,
        "aqs": None,
        "additional_countries": None,
    }


def process_tiktok_file(filepath):
    with open(filepath) as f:
        data = json.load(f)
    return {
        "platform": "TikTok",
        "social_id": data["basic"]["social_id"],
        "username": data["basic"]["username"],
        "fullname": data["basic"]["fullname"],
        "avatar_url": data["basic"]["avatar_url"],
        "is_verified": data["basic"]["is_verified"],
        "subscribers_count": data["metrics"]["subscribers_count"]["value"],
        "engagement_avg": data["metrics"]["er"]["performance"]["30d"]["value"],
        "video_views_avg": data["metrics"]["views_avg"]["performance"]["30d"]["value"],
        "likes_avg": data["metrics"]["alikes_avg"]["performance"]["30d"]["value"],
        "comments_avg": data["metrics"]["comments_avg"]["performance"]["30d"]["value"],
        "shares_avg": data["metrics"]["shares_avg"]["performance"]["30d"]["value"],
        "description": data["basic"]["description"],
        "tier": data["basic"]["tier"],
        "hs_value": data["metrics"]["hs_value"]["value"],
        "aqs": data["features"]["aqs"]["data"]["value"],
        "audience_geo_country_1_code": data["features"]["blogger_geo"]["data"][
            "country"
        ],
        "audience_geo_country_1_prc": None,  # Valor não presente no arquivo TikTok
        "blogger_thematics": None,  # Valor não presente no arquivo TikTok
        "additional_countries": None,
    }


def process_youtube_file(filepath):
    with open(filepath) as f:
        data = json.load(f)
    thematics_descriptions = map_thematics(
        "YouTube", data["features"]["blogger_thematics"]["data"]
    )
    additional_countries = [
        {"country": c["id"], "prc": c["prc"]}
        for c in data["features"]["audience_geo"]["data"]["countries"]
    ]
    return {
        "platform": "YouTube",
        "social_id": data["basic"]["social_id"],
        "username": data["basic"]["username"],
        "fullname": data["basic"]["fullname"],
        "avatar_url": data["basic"]["avatar_url"],
        "is_verified": data["basic"]["is_verified"],
        "subscribers_count": data["metrics"]["subscribers_count"]["value"],
        "engagement_avg": data["metrics"]["engagement_avg"]["performance"]["30d"][
            "value"
        ],
        "video_views_avg": data["metrics"]["video_views_avg"]["performance"]["30d"][
            "value"
        ],
        "likes_avg": data["metrics"]["likes_avg"]["performance"]["30d"]["value"],
        "comments_avg": data["metrics"]["comments_avg"]["performance"]["30d"]["value"],
        "shares_avg": None,  # Valor não presente no arquivo YouTube
        "audience_geo_country_1_code": (
            data["features"]["audience_geo"]["data"]["countries"][0]["id"]
            if data["features"]["audience_geo"]["data"]["countries"]
            else None
        ),
        "audience_geo_country_1_prc": (
            data["features"]["audience_geo"]["data"]["countries"][0]["prc"]
            if data["features"]["audience_geo"]["data"]["countries"]
            else None
        ),
        "blogger_thematics": thematics_descriptions,
        "description": None,
        "tier": None,
        "hs_value": None,
        "aqs": None,
        "additional_countries": additional_countries,
    }


def process_files_list(files_list, process_function):
    data_list = []
    for filepath in files_list:
        data = process_function(filepath)
        data_list.append(data)
    return pd.DataFrame(data_list)


def process_all_files(all_files):
    df_instagram = process_files_list(all_files["Instagram"], process_instagram_file)
    df_tiktok = process_files_list(all_files["TikTok"], process_tiktok_file)
    df_youtube = process_files_list(all_files["YouTube"], process_youtube_file)
    # Combinar todos os DataFrames
    df_combined = pd.concat(
        [df_instagram, df_tiktok, df_youtube],
        ignore_index=True,
        sort=False,
    )
    return df_combined


df_combined = process_all_files(all_files)
# Exibir 5 registros aleatórios

df_combined_sample = df_combined.sample(5)
# Garantir que haja ao menos um de cada plataforma
count = 0
while not all(
    [
        "Instagram" in df_combined_sample["platform"].values,
        "TikTok" in df_combined_sample["platform"].values,
        "YouTube" in df_combined_sample["platform"].values,
    ]
):
    df_combined_sample = df_combined.sample(5)
    count += 1
    if count > 100:
        raise Exception("Não foi possível encontrar um exemplo de cada plataforma.")

display(df_combined_sample)
df_combined.to_feather("dados_processados.feather")
# Out:
#        platform                 social_id        username  \
# 1142     TikTok       6780786175105467397         eaebraz
# 739   Instagram                 315205274         roninho
# 2094    YouTube  UCEUf_uUDUfJJ3XfgwOxm-0A    DanielSaboya
# 1941    YouTube  UCtpnpcN0iBupTk3MtWPzZrQ     ApelapatoGo
# 1199     TikTok       6905543418157827077  felipe.dantasf
#
#                     fullname  \
# 1142                    braz
# 739                  Roninho
# 2094  Dan-Sa / Daniel Saboya
# 1941            Apelapato999
# 1199      Felipe Dantas  🕵️🚨
#
#                                              avatar_url  is_verified  \
# 1142  https://p16-va-tiktok.ibyteimg.com/tos-maliva-...        False
# 739   https://cdn.hypeauditor.com/img/instagram/user...         True
# 2094  https://yt3.googleusercontent.com/ytc/AIdro_mU...        False
# 1941  https://yt3.googleusercontent.com/EK3KhR3qG2s6...        False
# 1199  https://p16-va-tiktok.ibyteimg.com/tos-maliva-...        False
#
#       subscribers_count  engagement_avg  authentic_engagement  \
# 1142            3697364           16.42                   NaN
# 739             5231891       173802.00               96186.0
# 2094           18746371          413.00                   NaN
# 1941            2895155          482.00                   NaN
# 1199            1400568           15.68                   NaN
#
#      audience_geo_country_1_code  ...  blogger_thematics video_views_avg  \
# 1142                          br  ...               None        559547.0
# 739                           br  ...               None             NaN
# 2094                          br  ...    [Music & Dance]         10476.0
# 1941                          br  ...               None        232973.0
# 1199                          br  ...               None        121977.0
#
#       likes_avg comments_avg shares_avg  \
# 1142      88018          166        634
# 739        None         None       None
# 2094        407            6       None
# 1941          0          482       None
# 1199      18664         1065       1000
#
#                                             description  tier     hs_value  \
# 1142  gosto de fazer graça por ai\ncontatoeaebraz@gm...   147  3940.016628
# 739                                                None  None          NaN
# 2094                                               None  None          NaN
# 1941                                               None  None          NaN
# 1199  Business: felipedlourencao@gmail.com\n🗞️Notíci...   147   470.113507
#
#        aqs                               additional_countries
# 1142    76                                               None
# 739   None                                               None
# 2094  None  [{'country': 'br', 'prc': 91.74}, {'country': ...
# 1941  None  [{'country': 'br', 'prc': 84.58}, {'country': ...
# 1199    92                                               None
#
# [5 rows x 21 columns]

# %%
df_combined.to_csv("dados_processados.csv", index=False)

# %%
# Verificando dados faltantes e nulos no DataFrame combinado
missing_data_summary = df_combined.isnull().sum()
missing_data_percentage = (df_combined.isnull().sum() / len(df_combined)) * 100

# Combinando resumo e percentual de dados faltantes
missing_data_df = pd.DataFrame(
    {
        "Missing Count": missing_data_summary,
        "Missing Percentage": missing_data_percentage,
    }
)


display(missing_data_df)
# Out:
#                              Missing Count  Missing Percentage
# platform                                 0            0.000000
# social_id                                0            0.000000
# username                                 0            0.000000
# fullname                                 0            0.000000
# avatar_url                               0            0.000000
# is_verified                              0            0.000000
# subscribers_count                        0            0.000000
# engagement_avg                           0            0.000000
# authentic_engagement                  1923           67.806770
# audience_geo_country_1_code              0            0.000000
# audience_geo_country_1_prc             976           34.414669
# blogger_thematics                     1206           42.524683
# video_views_avg                        913           32.193230
# likes_avg                              913           32.193230
# comments_avg                           913           32.193230
# shares_avg                            1860           65.585331
# description                           1860           65.585331
# tier                                  1860           65.585331
# hs_value                              1860           65.585331
# aqs                                   1860           65.585331
# additional_countries                  1889           66.607898

# %%
# Criando uma matriz de dados faltantes
missing_matrix = df_combined.isnull()
# Calculando a correlação entre os dados faltantes e a plataforma
missing_matrix_copy = missing_matrix.copy()
missing_matrix_copy["platform"] = df_combined["platform"]
missing_correlation = missing_matrix_copy.groupby("platform").mean().transpose()

# Exibindo as correlações fortes (acima de 0.7)
strong_correlations = missing_correlation[
    (missing_correlation > 0.7) | (missing_correlation < -0.7)
]
strong_correlations = strong_correlations.dropna(how="all", axis=0).dropna(
    how="all", axis=1
)


strong_correlations
# Out:
# platform                    Instagram  TikTok  YouTube
# authentic_engagement              NaN     1.0      1.0
# audience_geo_country_1_prc        NaN     1.0      NaN
# blogger_thematics                 NaN     1.0      NaN
# video_views_avg                   1.0     NaN      NaN
# likes_avg                         1.0     NaN      NaN
# comments_avg                      1.0     NaN      NaN
# shares_avg                        1.0     NaN      1.0
# description                       1.0     NaN      1.0
# tier                              1.0     NaN      1.0
# hs_value                          1.0     NaN      1.0
# aqs                               1.0     NaN      1.0
# additional_countries              1.0     1.0      NaN

# %%
# Criando o gráfico de calor para verificar a correlação entre dados faltantes e a plataforma
plt.figure(figsize=(12, 8))
sns.heatmap(
    missing_matrix.groupby(df_combined["platform"]).mean(),
    cmap="viridis",
    cbar=True,
    yticklabels=True,
)
plt.title("Correlação entre Dados Faltantes e a Plataforma")
plt.xlabel("Colunas")
plt.ylabel("Plataforma")
plt.show()

# %% [markdown]
# ### Observação:
# Era esperado que houvesse correlação total entre algumas plataformas e alguns tipos de dados faltantes, pois na modelagem inicial dos dados já haviamos percebido e tratado essas diferenças entre os datasets. Porém resolvi documentar aqui isso novamente e de forma gráfica para ficar mais claro o andamento que daremos as análises agora.

# %%
# Separando o DataFrame combinado em três datasets distintos por plataforma
df_instagram = df_combined[df_combined["platform"] == "Instagram"].copy()
df_tiktok = df_combined[df_combined["platform"] == "TikTok"].copy()
df_youtube = df_combined[df_combined["platform"] == "YouTube"].copy()


# Função para dropar colunas com 100% de correlação de dados faltantes com a plataforma
def drop_full_correlated_columns(df, platform_name, correlations):
    columns_to_drop = correlations[platform_name].dropna().index.tolist()
    return df.drop(columns=columns_to_drop)


# Dropar colunas com 100% de correlação com a plataforma específica
df_instagram_clean = drop_full_correlated_columns(
    df_instagram, "Instagram", strong_correlations
)
df_tiktok_clean = drop_full_correlated_columns(df_tiktok, "TikTok", strong_correlations)
df_youtube_clean = drop_full_correlated_columns(
    df_youtube, "YouTube", strong_correlations
)


# Salvando os datasets limpos para cada plataforma
df_instagram_clean_path = "dados_instagram_limpos.feather"
df_tiktok_clean_path = "dados_tiktok_limpos.feather"
df_youtube_clean_path = "dados_youtube_limpos.feather"

df_instagram_clean.to_feather(df_instagram_clean_path)
df_tiktok_clean.to_feather(df_tiktok_clean_path)
df_youtube_clean.to_feather(df_youtube_clean_path)

# Paths para os arquivos salvos
df_instagram_clean_path, df_tiktok_clean_path, df_youtube_clean_path
# Out:
# ('dados_instagram_limpos.feather',
#  'dados_tiktok_limpos.feather',
#  'dados_youtube_limpos.feather')

# %%
# Analisando dados faltantes e NaNs no dataset limpo do Instagram
instagram_missing_data_summary = df_instagram_clean.isnull().sum()
instagram_missing_data_percentage = (
    df_instagram_clean.isnull().sum() / len(df_instagram_clean)
) * 100

# Combinando resumo e percentual de dados faltantes
instagram_missing_data_df = pd.DataFrame(
    {
        "Missing Count": instagram_missing_data_summary,
        "Missing Percentage": instagram_missing_data_percentage,
    }
)
instagram_missing_data_df
# Out:
#                              Missing Count  Missing Percentage
# platform                                 0              0.0000
# social_id                                0              0.0000
# username                                 0              0.0000
# fullname                                 0              0.0000
# avatar_url                               0              0.0000
# is_verified                              0              0.0000
# subscribers_count                        0              0.0000
# engagement_avg                           0              0.0000
# authentic_engagement                     0              0.0000
# audience_geo_country_1_code              0              0.0000
# audience_geo_country_1_prc               0              0.0000
# blogger_thematics                       62              6.7908

# %%
categorias_unicas = []
for value in df_instagram_clean["blogger_thematics"].to_list():
    if isinstance(value, list):
        categorias_unicas += value
    else:
        categorias_unicas.append(value)
categorias_unicas = list(set(categorias_unicas))
print("Número de Categorias únicas: ", len(categorias_unicas))
print("Categorias únicas:")
pprint(categorias_unicas)
# Out:
# Número de Categorias únicas:  44
# Categorias únicas:
# ['Art/Artists',
#  'Travel',
#  'Family',
#  'Cinema & Actors/actresses',
#  'Sweets & Bakery',
#  'Literature & Journalism',
#  'Nature & landscapes',
#  'Sports with a ball',
#  'Winter sports',
#  'Gaming',
#  'Beauty',
#  'Accessories & Jewellery',
#  'Architecture & Urban Design',
#  'Shows',
#  'Racing Sports',
#  'Fashion',
#  'Music',
#  'Education',
#  'Humor & Fun & Happiness',
#  'Business & Careers',
#  'Clothing & Outfits',
#  'Finance & Economics',
#  'Management & Marketing',
#  'Animals',
#  'DIY & Design',
#  None,
#  'Shopping & Retail',
#  'Kids & Toys',
#  'Machinery & Technologies',
#  'Cars & Motorbikes',
#  'Extreme Sports & Outdoor activity',
#  'Modeling',
#  'Politics',
#  'Computers & Gadgets',
#  'Comics & sketches',
#  'Fitness & Gym',
#  'Lifestyle',
#  'Photography',
#  'Trainers & Coaches',
#  'Luxury',
#  'Science',
#  'Adult content',
#  'Water sports',
#  'Food & Cooking']

# %%
from collections import Counter

# Create a new DataFrame with the unique categories as columns
df_categories = pd.DataFrame(columns=categorias_unicas)

# Iterate over each row in df_instagram_clean
for index, row in df_instagram_clean.iterrows():
    # Get the blogger_thematics for the current row
    blogger_thematics = row["blogger_thematics"]

    # Set the value of the corresponding category column to True if it appears in blogger_thematics
    for category in categorias_unicas:
        if isinstance(blogger_thematics, list) and category in blogger_thematics:
            df_categories.loc[index, category] = True
        else:
            df_categories.loc[index, category] = False

# Display the resulting DataFrame
sorted(df_categories.sum(), reverse=True)
# Out:
# [259,
#  217,
#  213,
#  97,
#  70,
#  56,
#  51,
#  48,
#  35,
#  33,
#  32,
#  20,
#  16,
#  13,
#  13,
#  11,
#  7,
#  7,
#  7,
#  6,
#  6,
#  6,
#  5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  4,
#  3,
#  3,
#  3,
#  3,
#  2,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  0]

# %% [markdown]
# ### Observação:
# A única coluna com dados faltantes é blogger_thematics, com uma porcentagem relativamente baixa (6.79%).
# Todas as outras colunas estão completas, sem dados faltantes.

# %%
# Adicionando uma coluna que indica se 'blogger_thematics' está faltante
df_instagram_clean["blogger_thematics_missing"] = df_instagram_clean[
    "blogger_thematics"
].isnull()

# Verificando a correlação entre a ausência de 'blogger_thematics' e outras colunas
correlation_with_missing = (
    df_instagram_clean.drop(df_instagram_clean.select_dtypes(include="object"), axis=1)
    .corr()["blogger_thematics_missing"]
    .sort_values(ascending=False)
)


correlation_with_missing
# Out:
# blogger_thematics_missing     1.000000
# engagement_avg                0.104734
# authentic_engagement          0.099223
# audience_geo_country_1_prc    0.077879
# is_verified                  -0.079965
# subscribers_count            -0.085339
# Name: blogger_thematics_missing, dtype: float64

# %% [markdown]
# ### Interpretação:
# - Correlação Fraca: As correlações são todas bastante fracas, o que indica que a ausência de dados em blogger_thematics não está fortemente associada a nenhuma das outras características quantitativas dos influenciadores.
# - Possíveis Causas: A falta de dados em blogger_thematics pode ser devido a questões de coleta de dados ou preenchimento de informações específicas para alguns influenciadores.

# %%
# Selecionando exemplos de influenciadores com dados faltantes em 'blogger_thematics'
missing_thematics_examples = df_instagram_clean[
    df_instagram_clean["blogger_thematics_missing"]
].sample(5)


missing_thematics_examples
# Out:
#       platform    social_id         username                 fullname  \
# 138  Instagram   4159720905   camilamoura225             Camila Moura
# 720  Instagram  51729074689  realdiegoaguiar             Diego Aguiar
# 645  Instagram  50097981040      noisecrente  Nóis é Crente [Oficial]
# 441  Instagram   7388086938          kika.xz                     kika
# 589  Instagram   5759349317        menotody_            Meno Tody 🇧🇷🩸
#
#                                             avatar_url  is_verified  \
# 138  https://cdn.hypeauditor.com/img/instagram/user...         True
# 720  https://cdn.hypeauditor.com/img/instagram/user...         True
# 645  https://cdn.hypeauditor.com/img/instagram/user...        False
# 441  https://cdn.hypeauditor.com/img/instagram/user...        False
# 589  https://cdn.hypeauditor.com/img/instagram/user...         True
#
#      subscribers_count  engagement_avg  authentic_engagement  \
# 138            3023281        188955.0              140270.0
# 720           10801881         70484.0               44899.0
# 645            1375099       2344841.0             1782146.0
# 441            3962981        472812.0              324611.0
# 589            3084033        448784.0              328292.0
#
#     audience_geo_country_1_code  audience_geo_country_1_prc blogger_thematics  \
# 138                          br                       77.76              None
# 720                          br                       87.09              None
# 645                          br                       84.12              None
# 441                          br                       81.63              None
# 589                          br                       80.88              None
#
#      blogger_thematics_missing
# 138                       True
# 720                       True
# 645                       True
# 441                       True
# 589                       True

# %%
# import torch
# import requests
# from PIL import Image
# from transformers import BlipProcessor, BlipForConditionalGeneration

# processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
# model = BlipForConditionalGeneration.from_pretrained(
#     "Salesforce/blip-image-captioning-large", torch_dtype=torch.float32
# ).to("cuda")

# img_url = "https://cdn.hypeauditor.com/img/instagram/user/13577008.jpg?w=150&till=1722470340&sign=e4e69bda8904aec68207c086296f2f67"
# raw_image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")


# # unconditional image captioning
# inputs = processor(raw_image, return_tensors="pt", max_length=20).to(
#     "cuda", torch.float16
# )

# out = model.generate(**inputs)
# print(processor.decode(out[0], skip_special_tokens=True))
